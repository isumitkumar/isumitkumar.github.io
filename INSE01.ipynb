# %% [markdown]
# <a href="https://colab.research.google.com/github/isumitkumar/isumitkumar.github.io/blob/master/INSE01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# To read data
# and to collect from top

# %%
df = pd.read_csv("breast_cancer.csv")
df.head(10)
# Out:
#    Clump Thickness  Uniformity of Cell Size  Uniformity of Cell Shape  \
# 0                5                        1                         1
# 1                5                        4                         4
# 2                3                        1                         1
# 3                6                        8                         8
# 4                4                        1                         1
# 5                8                       10                        10
# 6                1                        1                         1
# 7                2                        1                         2
# 8                2                        1                         1
# 9                4                        2                         1
#
#    Marginal Adhesion  Single Epithelial Cell Size  Bare Nuclei  \
# 0                  1                            2            1
# 1                  5                            7           10
# ...

# %%
df['Clump Thickness']
# Out:
# 0      5
# 1      5
# 2      3
# 3      6
# 4      4
#       ..
# 678    3
# 679    2
# 680    5
# 681    4
# 682    4
# Name: Clump Thickness, Length: 683, dtype: int64

# %% [markdown]
# TO check size

# %%
df.shape
# Out:
# (683, 10)

# %% [markdown]
# to see data from bottom

# %%
df.tail(12)
# Out:
#      Clump Thickness  Uniformity of Cell Size  Uniformity of Cell Shape  \
# 671                3                        1                         1
# 672                4                        1                         1
# 673                1                        1                         1
# 674                1                        1                         1
# 675                5                       10                        10
# 676                3                        1                         1
# 677                3                        1                         1
# 678                3                        1                         1
# 679                2                        1                         1
# 680                5                       10                        10
# 681                4                        8                         6
# 682                4                        8                         8
#
# ...
